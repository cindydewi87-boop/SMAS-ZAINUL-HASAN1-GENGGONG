# %%
import time

detik = int(input("Ingin mengingatkan berapa detik lagi? "))
pesan = input("Pesan pengingat: ")

time.sleep(detik)
print("⏰ Pengingat:", pesan)
# Out:
# Ingin mengingatkan berapa detik lagi? 2
# Pesan pengingat: ayooooooooooooooooooooooooooooooooooo
# ⏰ Pengingat: ayooooooooooooooooooooooooooooooooooo
